# %% [markdown]
# # Forecasting Financial Statements with `finstmt`
#
# First import the necessary classes and `pandas`.

# %%
import os
os.chdir('..')
from finstmt import FinancialStatements, IncomeStatements, BalanceSheets
import pandas as pd

# %% [markdown]
# ## Load Financial Statements

# %%
root_folder = os.path.sep.join(['..', 'tests', 'sources', 'stockrow', 'CAT'])

inc_path = os.path.join(root_folder, 'annual_income.csv')
bs_path = os.path.join(root_folder, 'annual_bs.csv')

inc_df = pd.read_csv(inc_path, index_col=0)
bs_df = pd.read_csv(bs_path, index_col=0)

bs = BalanceSheets.from_df(bs_df)
inc = IncomeStatements.from_df(inc_df)
stmts = FinancialStatements(inc, bs)
# Out:
# /home/nick/Dropbox/Python/py-finstmt/finstmt/findata/database.py:78: UserWarning: Previously had ebit extracted from "Operating Income". Replacing with value from "EBIT"
#   warnings.warn(f'Previously had {item_config.key} '

# %% [markdown]
# ### View Existing Statements

# %%
stmts
# Out:
# FinancialStatements(income_statements=IncomeStatements(statements={Timestamp('2009-12-31 00:00:00'): IncomeStatementData(revenue=32396000000.0, cogs=24931000000.0, sga=3645000000.0, int_exp=389000000.0, tax_exp=270000000.0, rd_exp=1421000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=6888000000.0, ebit=1014000000.0, ebt=625000000.0, net_income=895000000.0), Timestamp('2010-12-31 00:00:00'): IncomeStatementData(revenue=42588000000.0, cogs=31281000000.0, sga=4248000000.0, int_exp=343000000.0, tax_exp=968000000.0, rd_exp=1905000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=7344000000.0, ebit=4011000000.0, ebt=3668000000.0, net_income=2700000000.0), Timestamp('2011-12-31 00:00:00'): IncomeStatementData(revenue=60138000000.0, cogs=44404000000.0, sga=5203000000.0, int_exp=396000000.0, tax_exp=1720000000.0, rd_exp=2297000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=8581000000.0, ebit=7044000000.0, ebt=6648000000.0, net_income=4928000000.0), Timestamp('2012-12-31 00:00:00'): IncomeStatementData(revenue=65875000000.0, cogs=47852000000.0, sga=5919000000.0, int_exp=467000000.0, tax_exp=2528000000.0, rd_exp=2466000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=9450000000.0, ebit=8676000000.0, ebt=8209000000.0, net_income=5681000000.0), Timestamp('2013-12-31 00:00:00'): IncomeStatementData(revenue=55656000000.0, cogs=41454000000.0, sga=5547000000.0, int_exp=465000000.0, tax_exp=1319000000.0, rd_exp=2046000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=8574000000.0, ebit=5573000000.0, ebt=5108000000.0, net_income=3789000000.0), Timestamp('2014-12-31 00:00:00'): IncomeStatementData(revenue=55184000000.0, cogs=41342000000.0, sga=6529000000.0, int_exp=484000000.0, tax_exp=692000000.0, rd_exp=2380000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=10528000000.0, ebit=3628000000.0, ebt=3144000000.0, net_income=2452000000.0), Timestamp('2015-12-31 00:00:00'): IncomeStatementData(revenue=47011000000.0, cogs=34133000000.0, sga=4951000000.0, int_exp=507000000.0, tax_exp=916000000.0, rd_exp=2119000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=9093000000.0, ebit=3935000000.0, ebt=3428000000.0, net_income=2512000000.0), Timestamp('2016-12-31 00:00:00'): IncomeStatementData(revenue=38537000000.0, cogs=28640000000.0, sga=4383000000.0, int_exp=505000000.0, tax_exp=192000000.0, rd_exp=1853000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=8735000000.0, ebit=630000000.0, ebt=125000000.0, net_income=67000000.0), Timestamp('2017-12-31 00:00:00'): IncomeStatementData(revenue=45462000000.0, cogs=31906000000.0, sga=4999000000.0, int_exp=531000000.0, tax_exp=3339000000.0, rd_exp=1842000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=9096000000.0, ebit=4624000000.0, ebt=4093000000.0, net_income=754000000.0), Timestamp('2018-12-31 00:00:00'): IncomeStatementData(revenue=54722000000.0, cogs=37719000000.0, sga=5478000000.0, int_exp=404000000.0, tax_exp=1698000000.0, rd_exp=1850000000.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=8710000000.0, ebit=8249000000.0, ebt=7845000000.0, net_income=6147000000.0)}), balance_sheets=BalanceSheets(statements={Timestamp('2009-12-31 00:00:00'): BalanceSheetData(cash=4867000000, st_invest=0, receivables=27162000000, inventory=6360000000, lt_invest=105000000, def_tax_st=0, other_current_assets=0, gross_ppe=0, dep=0, goodwill=2734000000, def_tax_lt=3930000000, other_lt_assets=0, payables=2993000000, current_lt_debt=0, st_debt=9784000000, lt_debt=21847000000, deferred_rev=0, tax_liab_st=0, other_current_liab=0, tax_lia ...

# %% [markdown]
# ## Run a Forecast

# %% [markdown]
# ### Set the Default Method
#
# This is not a necessary step, but this is the way to change the default forecast method. The default is already `cagr` and so this doesn't actually have an effect.

# %%
stmts.config.update_all(['forecast_config', 'method'], 'cagr')

# %% [markdown]
# ### Run the First Forecast
#
# Forecasts are run using `.forecast()` and produce `ForecastedFinancialStatements`. It is usually good practice to first run a forecast, then view the results, then adjust as needed.

# %%
fcst = stmts.forecast()
# Out:
# INFO: Forecasting Income Statement
#   0%|          | 0/16 [00:00<?, ?it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Depreciation & Amortization Expense as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Operating Expenses as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  62%|██████▎   | 10/16 [00:00<00:00, 91.05it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Gain on Sale of Investments as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Gain on Sale of Assets as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Impairment Expense as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# 100%|██████████| 16/16 [00:00<00:00, 104.38it/s]
# INFO: Forecasting Balance Sheet
#   0%|          | 0/37 [00:00<?, ?it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Short-Term Investments as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Deferred Tax Assets, Current as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  16%|█▌        | 6/37 [00:00<00:00, 58.80it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Current Assets as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Grosss Property, Plant & Equipment as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Accumulated Depreciation as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  27%|██▋       | 10/37 [00:00<00:00, 50.82it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:62: RuntimeWarning: invalid value encountered in true_divide
#   next_value = last_value / (1 + cagr)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Long-Term Assets as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  51%|█████▏    | 19/37 [00:00<00:00, 57.10it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Current Portion of Long-Term Debt as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Tax Liabilities, Short-Term as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Current Liabilities as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Deferred Revenue as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Tax Liabilities, Long-Term as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  76%|███████▌  | 28/37 [00:00<00:00, 63.84it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Long-Term Liabilities as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Common Stock as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Minority Interest as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# 100%|██████████| 37/37 [00:00<00:00, 70.14it/s]

# %% [markdown]
# > Note: Warnings are raised because CAGR is the default method but it is not suitable for items which begin with 0
#
# Now view the forecast.

# %%
fcst
# Out:
# ForecastedFinancialStatements(income_statements=IncomeStatements(statements={Timestamp('2019-12-31 00:00:00', freq='A-DEC'): IncomeStatementData(revenue=57667220437.771454, cogs=39313545944.27838, sga=5705772840.60267, int_exp=405531450.9237179, tax_exp=2089169669.9257543, rd_exp=1899457118.2120335, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=7605229958.814703, ebit=10748444534.67837, ebt=10342913083.754652, net_income=8253743413.828897), Timestamp('2020-12-31 00:00:00', freq='A-DEC'): IncomeStatementData(revenue=60770957074.275894, cogs=40975500270.76241, sga=5943016376.151709, int_exp=407068707.14924717, tax_exp=2166860856.397932, rd_exp=1950236402.1223583, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=7893252778.274067, ebit=11902204025.239414, ebt=11495135318.090168, net_income=9328274461.692236), Timestamp('2021-12-31 00:00:00', freq='A-DEC'): IncomeStatementData(revenue=64041741490.01525, cogs=42707712624.523705, sga=6190124393.994764, int_exp=408611790.682862, tax_exp=2239912369.868477, rd_exp=2002373197.9500213, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=8192497591.944786, ebit=13141531273.54676, ebt=12732919482.8639, net_income=10493007112.995422), Timestamp('2022-12-31 00:00:00', freq='A-DEC'): IncomeStatementData(revenue=67488564448.0005, cogs=44513153117.50712, sga=6447507054.98492, int_exp=410160723.6142563, tax_exp=2308507442.215454, rd_exp=2055903796.8449519, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=8503410851.829871, ebit=14472000478.663513, ebt=14061839755.049257, net_income=11753332312.833803), Timestamp('2023-12-31 00:00:00', freq='A-DEC'): IncomeStatementData(revenue=71120900607.64575, cogs=46394917421.18866, sga=6715591574.283874, int_exp=411715528.11686, tax_exp=2372822562.3612084, rd_exp=2110865460.149346, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=8826457034.43322, ebit=15899526152.023872, ebt=15487810623.907013, net_income=13114988061.545805)}), balance_sheets=BalanceSheets(statements={Timestamp('2019-12-31 00:00:00', freq='A-DEC'): BalanceSheetData(cash=8242449478.280024, st_invest=0.0, receivables=32415938592.3646, inventory=12235594949.244326, lt_invest=0.0, def_tax_st=0.0, other_current_assets=0.0, gross_ppe=0.0, dep=0.0, goodwill=9046459696.624979, def_tax_lt=1301450391.2211661, other_lt_assets=0.0, payables=7681837473.643944, current_lt_debt=0.0, st_debt=11746611523.392265, lt_debt=25339312566.23286, deferred_rev=0.0, tax_liab_st=0.0, other_current_liab=0.0, tax_liab_lt=0.0, deposit_liab=1245630356.6922483, other_lt_liab=0.0, common_stock=0.0, minority_interest=0.0, other_income=-1553858022.6100283, retained_earnings=31777094254.750103, cash_and_st_invest=8242449478.280024, total_current_assets=39975981658.00781, net_ppe=13698894523.433386, total_non_current_assets=40693667958.95777, total_assets=80643388633.05789, total_current_liab=29360312489.995544, total_debt=37085491303.929756, total_non_current_liab=36688708046.092804, total_liab=65986667422.16877, total_equity=14767663132.111275, total_liab_and_equity=80718996577.10303), Timestamp('2020-12-31 00:00:00', freq='A-DEC'): BalanceSheetData(cash=8646808374.952097, st_invest=0.0, receivables=32941254422.5196, inventory=12985496032.784563, lt_invest=0.0, def_tax_st=0.0, other_current_assets=0.0, gross_ppe=0.0, dep=0.0, goodwill=10086077525.592817, def_tax_lt=1177048728.846231, other_lt_assets=0.0, payables=8369114589.629892, current_lt_debt=0.0, st_debt=11943467695.100143, lt_debt=25683230453.16986, deferred_rev=0.0, tax_liab_st=0.0, other_current_liab=0.0, tax_liab_lt=0.0, deposit_liab=1248266279.5762331, other_lt_liab=0.0, common_stock=0.0, minority_interest=0.0, other_income=-1433773607.1434367, retained_earnings=33187094333.16699, cash_and_st_invest= ...

# %% [markdown]
# And the plot:

# %%
fcst.plot()

# %% [markdown]
# It is also possible to plot a subset. Let's focus on only a few items for sake of example.

# %%
fcst.plot(subset=['revenue', 'cogs', 'cash'])

# %% [markdown]
# ### Change Methods and Re-Run Forecast
#
# After viewing the plots, the appropriate methods for forecasting each item should be chosen. Then they can be updated.

# %%
stmts.config.update('cash', ['forecast_config', 'method'], 'trend')
stmts.config.update('cogs', ['forecast_config', 'method'], 'mean')

# %% [markdown]
# Now re-run the forecast.

# %%
fcst = stmts.forecast()
# Out:
# INFO: Forecasting Income Statement
#   0%|          | 0/16 [00:00<?, ?it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Depreciation & Amortization Expense as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Operating Expenses as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  44%|████▍     | 7/16 [00:00<00:00, 66.34it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Gain on Sale of Investments as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Gain on Sale of Assets as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Impairment Expense as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# 100%|██████████| 16/16 [00:00<00:00, 61.55it/s]
# INFO: Forecasting Balance Sheet
#   0%|          | 0/37 [00:00<?, ?it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Short-Term Investments as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Deferred Tax Assets, Current as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  16%|█▌        | 6/37 [00:00<00:00, 58.63it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Current Assets as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Grosss Property, Plant & Equipment as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  24%|██▍       | 9/37 [00:00<00:00, 43.07it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Accumulated Depreciation as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  32%|███▏      | 12/37 [00:00<00:00, 33.74it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:62: RuntimeWarning: invalid value encountered in true_divide
#   next_value = last_value / (1 + cagr)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Long-Term Assets as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  41%|████      | 15/37 [00:00<00:00, 30.89it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Current Portion of Long-Term Debt as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Tax Liabilities, Short-Term as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Current Liabilities as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  62%|██████▏   | 23/37 [00:00<00:00, 37.41it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Deferred Revenue as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Tax Liabilities, Long-Term as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Other Long-Term Liabilities as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
#  81%|████████  | 30/37 [00:00<00:00, 42.78it/s]/home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Common Stock as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# /home/nick/Dropbox/Python/py-finstmt/finstmt/forecast/models/cagr.py:24: UserWarning: CAGR not an appropriate method for Minority Interest as y_0 is 0. Setting to 0 growth
#   warnings.warn(message)
# 100%|██████████| 37/37 [00:00<00:00, 48.83it/s]

# %% [markdown]
# And plot the results:

# %%
fcst.plot(subset=['revenue', 'cogs', 'cash'])

# %% [markdown]
# Now the methods for those forecasts has been updated.
#
# ### Adjusting an Existing Forecast
#
# While it is possible to use the `manual` forecast type and pass in the desired growth rates or levels from the beginning, it is often more convenient to first run the forecast, then simply adjust it. The `.to_manual` method of the forecast was added for this purpose.
#
# Either `adjustments` or `replacements` can be passed while updating, and either the level of the item or the growth in the item can be used for the new manual forecast.

# %%
fcst.forecasts['cash'].to_manual(adjustments=[0, 0.4, 0, 0, 0])  # boost second forecast period cash growth by 40%
fcst.forecasts['revenue'].to_manual(use_levels=True, replacements={1: 8e10})  # set second forecast period revenue to 80,000,000,000

# %% [markdown]
# The existing forecast is updated without running a new one. Now view the plots:

# %%
fcst.plot(subset=['revenue', 'cogs', 'cash'])
