# %% [markdown]
# # Intro to Graphics
#
# This notebook gives an overview on basic plots, charts, and graphs in Python. It requires knowledge of `pandas` `DataFrame`s covered in "Intro to Pandas and Table Visualization.ipynb".

# %% [markdown]
# ## Required Imports
#
# We will need to import `pandas` as usual. But here since we will need to do plotting, there is a specific command we need to run at the beginning of the notebook: `%matplotlib inline`. This basically allows the graphics to be displayed in the notebook. The `matplotlib` part comes because `pandas` uses `matplotlib` under the hood to generate its plots.

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Plotting with Pandas

# %% [markdown]
# Let's quickly set up a `DataFrame` with some data so we can create some plots from it.

# %%
df = pd.DataFrame()
df['Values'] = [100.12, 110.5, 105.2, 106.7, 110.2, 98.5, 94.2, 91.1, 93.12, 94.02, 92.17]
df['t'] = [i + 1 for i in range(11)]
df
# Out:
#     Values   t
# 0   100.12   1
# 1   110.50   2
# 2   105.20   3
# 3   106.70   4
# 4   110.20   5
# 5    98.50   6
# 6    94.20   7
# 7    91.10   8
# 8    93.12   9
# 9    94.02  10
# 10   92.17  11

# %% [markdown]
# We can immediately call `.plot` on the `DataFrame` and it will try to give us a reasonable plot.

# %%
df.plot()

# %% [markdown]
# Here we can see it gave us the values, but over the index and not over time. It also plotted time separately, when really we want to see the values versus time. By specifying `y` and `x`, we can fix this:

# %%
df.plot(y='Values', x='t')

# %% [markdown]
# Now we can indeed see the values plotted over time. This is a line plot. We could have also created it via `.plot.line()`:

# %%
df.plot.line(y='Values', x='t')

# %% [markdown]
# You can see the available plot types in `pandas` by doing `df.plot.` and then pressing tab. Below is just my version that allows that to stay in the completed notebook:

# %%
[attr for attr in dir(df.plot) if not attr.startswith('_')]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %% [markdown]
# ### Area
#
# Like a line graph, but colors area under each line.

# %%
df.plot.area(y='Values', x='t')

# %% [markdown]
# ### Bar Graphs
#
# `bar` for vertical and `barh` for horizontal:

# %%
df.plot.bar(y='Values', x='t')

# %%
df.plot.barh(y='Values', x='t')

# %% [markdown]
# ### Box and Whisker Plot
#
# Gives a good summary info of the distribution of the data.

# %%
df.plot.box(y='Values', x='t')

# %% [markdown]
# ### Density and Histogram
#
# These both plot the frequency/probability of the various values. The `density` or `kde` plot is basically a smoothed histogram.

# %%
df.plot.density(y='Values', x='t')

# %%
df.plot.hist(y='Values', x='t')

# %% [markdown]
# ### Pie Charts
#
# Who doesn't love a good pie chart?

# %%
df.plot.pie(y='Values', x='t')

# %% [markdown]
# ### Scatter Chart
#
# Like a line chart, but not connected.

# %%
df.plot.scatter(y='Values', x='t')
