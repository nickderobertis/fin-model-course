# %% [markdown]
# # Forecasting Quarterly Financial Statements
#
# This exercise is focused on forecasting quarterly financials. The lessons learned can apply to many complex time series, not only quarterly financials.
#
# We have already covered how to forecast simple time series, those which seem to have a linear or constant path over timne. But if there are any other patterns in the data, such as seasonality, we must use more complex models to handle them.

# %% [markdown]
# ## Load Financial Statement Data
#
# Here I will use my `finstmt` package to load the quarterly financials for Walmart.

# %%
from finstmt import IncomeStatements, BalanceSheets, FinancialStatements
import pandas as pd

bs_df = pd.read_excel('WMT Balance Sheet.xlsx', index_col=0)
inc_df = pd.read_excel('WMT Income Statement.xlsx', index_col=0)

bs_data = BalanceSheets.from_df(bs_df)
inc_data = IncomeStatements.from_df(inc_df)
stmts = FinancialStatements(inc_data, bs_data)
# Out:
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 7458000000.0 for ebit extracted from operating income. Replacing with 7279000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5737000000.0 for ebit extracted from operating income. Replacing with 5645000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6190000000.0 for ebit extracted from operating income. Replacing with 6096000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5611000000.0 for ebit extracted from operating income. Replacing with 5510000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 8004000000.0 for ebit extracted from operating income. Replacing with 8922000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5896000000.0 for ebit extracted from operating income. Replacing with 5761000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6383000000.0 for ebit extracted from operating income. Replacing with 6269000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5878000000.0 for ebit extracted from operating income. Replacing with 5778000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 8334000000.0 for ebit extracted from operating income. Replacing with 8135000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6387000000.0 for ebit extracted from operating income. Replacing with 6273000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6698000000.0 for ebit extracted from operating income. Replacing with 6603000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6093000000.0 for ebit extracted from operating income. Replacing with 5963000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 8580000000.0 for ebit extracted from operating income. Replacing with 8378000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6438000000.0 for ebit extracted from operating income. Replacing with 6333000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6777000000.0 for ebit extracted from operating income. Replacing with 6678000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6310000000.0 for ebit extracted from operating income. Replacing with 6190000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 7347000000.0 for ebit extracted from operating income. Replacing with 7261000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6193000000.0 for ebit extracted from operating income. Replacing with 6099000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6740000000.0 for ebit extracted from operating income. Replacing with 6776000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6265000000.0 for ebit extracted from operating income. Replacing with 6170000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 7949000000.0 for ebit extracted from operating income. Replacing with 7764000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5680000000.0 for ebit extracted from operating income. Replacing with 5757000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6069000000.0 for ebit extracted from operating income. Replacing with 5933000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5714000000.0 for ebit extracted from operating income. Replacing with 5625000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6642000000.0 for ebit extracted from operating income. Replacing with 6485000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5275000000.0 for ebit extracted from operating income. Replacing with 5162000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6165000000.0 for ebit extracted from operating income. Replacing with 6071000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5119000000.0 for ebit extracted from operating income. Replacing with 4975000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6205000000.0 for ebit extracted from operating income. Replacing with 6006000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5237000000.0 for ebit extracted from operating income. Replacing with 5159000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5969000000.0 for ebit extracted from operating income. Replacing with 5014000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 4764000000.0 for ebit extracted from operating income. Replacing with 3307000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 4467000000.0 for ebit extracted from operating income. Replacing with 3312000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5154000000.0 for ebit extracted from operating income. Replacing with 3210000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5750000000.0 for ebit extracted from operating income. Replacing with 818000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 4986000000.0 for ebit extracted from operating income. Replacing with 3062000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 6067000000.0 for ebit extracted from operating income. Replacing with 6207000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 4945000000.0 for ebit extracted from operating income. Replacing with 5766000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/finstmt/findata/database.py:72: UserWarning: Previously had 5583000000.0 for ebit extracted from operating income. Replacing with 5484000000.0 from ebit
#   warnings.warn(f'Previously had {data_dict[item_config.key]} for {item_config.key} '

# %% [markdown]
# ### What just happened?

# %% [markdown]
# Don't worry about all the warnings. It's just saying that both operating income and EBIT were found in the statement data, and so it's using EBIT for the EBIT measure. It prints a warning because some companies report operating income but not EBIT, in which case we want to use operating income as EBIT. So the package hits operating income first, sets EBIT to that, but then later finds EBIT in the file, and raises the warning to let you know it found two possible values for the same item. In a future release I will get it to raise only a single warning for this, rather than one for every time period.

# %% [markdown]
# Let's view the data.

# %%
stmts
# Out:
# FinancialStatements(income_statements=IncomeStatements(statements={Timestamp('2010-01-31 00:00:00'): IncomeStatementData(revenue=113622000000.0, cogs=84740000000.0, sga=21424000000.0, int_exp=522000000.0, tax_exp=1999000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=21424000000.0, ebit=7279000000.0, ebt=6757000000.0, net_income=4758000000.0), Timestamp('2010-04-30 00:00:00'): IncomeStatementData(revenue=99811000000.0, cogs=74618000000.0, sga=19456000000.0, int_exp=522000000.0, tax_exp=1822000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=19456000000.0, ebit=5645000000.0, ebt=5123000000.0, net_income=3301000000.0), Timestamp('2010-07-31 00:00:00'): IncomeStatementData(revenue=103726000000.0, cogs=77438000000.0, sga=20098000000.0, int_exp=542000000.0, tax_exp=1958000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=20098000000.0, ebit=6096000000.0, ebt=5554000000.0, net_income=3596000000.0), Timestamp('2010-10-31 00:00:00'): IncomeStatementData(revenue=101952000000.0, cogs=75819000000.0, sga=20522000000.0, int_exp=569000000.0, tax_exp=1505000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=20522000000.0, ebit=5510000000.0, ebt=4941000000.0, net_income=3436000000.0), Timestamp('2011-01-31 00:00:00'): IncomeStatementData(revenue=116360000000.0, cogs=87071000000.0, sga=21285000000.0, int_exp=572000000.0, tax_exp=2294000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=21285000000.0, ebit=8922000000.0, ebt=8350000000.0, net_income=6056000000.0), Timestamp('2011-04-30 00:00:00'): IncomeStatementData(revenue=104189000000.0, cogs=78177000000.0, sga=20116000000.0, int_exp=562000000.0, tax_exp=1800000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=20116000000.0, ebit=5761000000.0, ebt=5199000000.0, net_income=3399000000.0), Timestamp('2011-07-31 00:00:00'): IncomeStatementData(revenue=109366000000.0, cogs=81770000000.0, sga=21213000000.0, int_exp=600000000.0, tax_exp=1868000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=21213000000.0, ebit=6269000000.0, ebt=5669000000.0, net_income=3801000000.0), Timestamp('2011-10-31 00:00:00'): IncomeStatementData(revenue=110226000000.0, cogs=82591000000.0, sga=21757000000.0, int_exp=600000000.0, tax_exp=1842000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=21757000000.0, ebit=5778000000.0, ebt=5178000000.0, net_income=3336000000.0), Timestamp('2012-01-31 00:00:00'): IncomeStatementData(revenue=122728000000.0, cogs=92455000000.0, sga=21939000000.0, int_exp=558000000.0, tax_exp=2414000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=21939000000.0, ebit=8135000000.0, ebt=7577000000.0, net_income=5163000000.0), Timestamp('2012-04-30 00:00:00'): IncomeStatementData(revenue=113010000000.0, cogs=85178000000.0, sga=21445000000.0, int_exp=573000000.0, tax_exp=1958000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=21445000000.0, ebit=6273000000.0, ebt=5700000000.0, net_income=3742000000.0), Timestamp('2012-07-31 00:00:00'): IncomeStatementData(revenue=114282000000.0, cogs=85643000000.0, sga=21941000000.0, int_exp=555000000.0, tax_exp=2032000000.0, rd_exp=0.0, dep_exp=0, other_op_exp=0, gain_on_sale_invest=0, gain_on_sale_asset=0, impairment=0, op_exp=21941000000.0, ebit=6603000000.0, ebt=6048000000.0, net_income=4016000000.0), Timestamp('2012-10-31 00:00:00'): IncomeStatementData(revenue=113800000000.0, cogs=85470000000.0, sga=22237000000.0, int_exp=590000000.0, tax_exp=1738000000.0, r ...

# %% [markdown]
# As you can see, we have quite a bit of data, 39 periods. This is plenty to get a pretty accurate forecast even considering seasonality.

# %% [markdown]
# ## Simple or Complex Time-Series?
#
# We can determine what type of time-series we are dealing with by plotting it. Let's take a look at sales.

# %%
# %matplotlib inline
stmts.revenue.plot.line()

# %% [markdown]
# That definitely does not look linear. There are distinct patterns happening within every year. The data shows a very distinct seasonality. Therefore the simple trend, average, and recent value models will not be able to capture the patterns in the time-series.

# %% [markdown]
# ## Forecasting Using the OLS Dummy Variable Approach
#
# This approach can work well for quarterly financials which show simple seasonality (same kind of pattern every year). It does not require any complex tooling or models. It is just a regular trend regression, but then we add some additional $X$ variables to capture the seasonality.
#
# We are going to add dummy variables, one for each quarter of the year. A dummy variable is just a variable which is either 1 or 0, basically meaning true or false, yes or no, etc. What we are going to construct is four variables. The first will be 1 if the time period is in the first quarter of the year and 0 otherwise. The second will be 1 if the time period is in the second quarter of the year and 0 otherwise. And so on for the third and fourth quarters.

# %% [markdown]
# ### Construct Dummy Variables

# %% [markdown]
# Let's take a quick look again at what we're working with.

# %%
stmts.revenue.head(10)
# Out:
# 2010-01-31    1.136220e+11
# 2010-04-30    9.981100e+10
# 2010-07-31    1.037260e+11
# 2010-10-31    1.019520e+11
# 2011-01-31    1.163600e+11
# 2011-04-30    1.041890e+11
# 2011-07-31    1.093660e+11
# 2011-10-31    1.102260e+11
# 2012-01-31    1.227280e+11
# 2012-04-30    1.130100e+11
# dtype: float64

# %% [markdown]
# Let's convert this to a `DataFrame` so we can add additional columns.

# %%
rev_df = pd.DataFrame(stmts.revenue)
rev_df.columns = ['Revenue']
rev_df.head()
# Out:
#                  Revenue
# 2010-01-31  1.136220e+11
# 2010-04-30  9.981100e+10
# 2010-07-31  1.037260e+11
# 2010-10-31  1.019520e+11
# 2011-01-31  1.163600e+11

# %% [markdown]
# Let's add the time variable, similarly to when we did the trend regressions.

# %%
rev_df['t'] = range(len(rev_df))
rev_df.head()
# Out:
#                  Revenue  Month  t
# 2010-01-31  1.136220e+11      1  0
# 2010-04-30  9.981100e+10      4  1
# 2010-07-31  1.037260e+11      7  2
# 2010-10-31  1.019520e+11     10  3
# 2011-01-31  1.163600e+11      1  4

# %%
rev_df.tail()  # end of df
# Out:
#                  Revenue  Month   t
# 2018-07-31  1.280280e+11      7  34
# 2018-10-31  1.248940e+11     10  35
# 2019-01-31  1.387930e+11      1  36
# 2019-04-30  1.239250e+11      4  37
# 2019-07-31  1.303770e+11      7  38

# %% [markdown]
# We can create a variable which contains the month of the year. Then we can construct dummy variables out of this.

# %%
rev_df['Month'] = [date.month for date in rev_df.index]
rev_df.head()
# Out:
#                  Revenue  Month  t
# 2010-01-31  1.136220e+11      1  0
# 2010-04-30  9.981100e+10      4  1
# 2010-07-31  1.037260e+11      7  2
# 2010-10-31  1.019520e+11     10  3
# 2011-01-31  1.163600e+11      1  4

# %% [markdown]
# We could certainly write up some if conditions in a loop to create these dummy variables. But this is such a common operation that `pandas` has made a function for this, `get_dummies()`.

# %%
reg_df = pd.get_dummies(rev_df, columns=['Month'])
reg_df.head(10)
# Out:
#                  Revenue  t  Month_1  Month_4  Month_7  Month_10
# 2010-01-31  1.136220e+11  0        1        0        0         0
# 2010-04-30  9.981100e+10  1        0        1        0         0
# 2010-07-31  1.037260e+11  2        0        0        1         0
# 2010-10-31  1.019520e+11  3        0        0        0         1
# 2011-01-31  1.163600e+11  4        1        0        0         0
# 2011-04-30  1.041890e+11  5        0        1        0         0
# 2011-07-31  1.093660e+11  6        0        0        1         0
# 2011-10-31  1.102260e+11  7        0        0        0         1
# 2012-01-31  1.227280e+11  8        1        0        0         0
# 2012-04-30  1.130100e+11  9        0        1        0         0

# %% [markdown]
# Now this is set up as we need it for the regression. Let's just wrap this up in a function.

# %%
def reg_df_monthly_dummies_from_by_date_series(series, column_name):
    """
    Takes a series which has dates as the index, and creates a DataFrame with dummy variables for months of those dates
    """
    df = pd.DataFrame(series)
    df.columns = [column_name]
    df['t'] = range(len(rev_df))
    df['Month'] = [date.month for date in df.index]
    reg_df = pd.get_dummies(df, columns=['Month'])
    return reg_df

reg_df_monthly_dummies_from_by_date_series(stmts.cash, 'Cash').head()
# Out:
#                    Cash  t  Month_1  Month_4  Month_7  Month_10
# 2010-01-31   7907000000  0        1        0        0         0
# 2010-04-30   8516000000  1        0        1        0         0
# 2010-07-31  10195000000  2        0        0        1         0
# 2010-10-31  10616000000  3        0        0        0         1
# 2011-01-31   7395000000  4        1        0        0         0

# %% [markdown]
# ### Fit Model (Run Regression)

# %% [markdown]
# So now we have our regression `DataFrame`, let's look at that again.

# %%
reg_df.head()
# Out:
#                  Revenue  Month_1  Month_4  Month_7  Month_10
# 2010-01-31  1.136220e+11        1        0        0         0
# 2010-04-30  9.981100e+10        0        1        0         0
# 2010-07-31  1.037260e+11        0        0        1         0
# 2010-10-31  1.019520e+11        0        0        0         1
# 2011-01-31  1.163600e+11        1        0        0         0

# %% [markdown]
# We will need to tell `statsmodels` to pick up all the Month columns. We can either type them out manually, or we can use this code to get the names:

# %%
month_cols = [col for col in reg_df.columns if 'Month' in col]
month_cols
# Out:
# ['Month_1', 'Month_4', 'Month_7', 'Month_10']

# %%
x_cols = ['t'] + month_cols
x_cols
# Out:
# ['t', 'Month_1', 'Month_4', 'Month_7', 'Month_10']

# %% [markdown]
# Now actually run the regression.

# %%
import statsmodels.api as sm

model = sm.OLS(reg_df['Revenue'], sm.add_constant(reg_df[x_cols]), hasconst=True)
results = model.fit()
results.summary()
# Out:
# /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     115.4
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):           2.79e-19
# Time:                        04:02:36   Log-Likelihood:                -896.78
# No. Observations:                  39   AIC:                             1804.
# Df Residuals:                      34   BIC:                             1812.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.605e+10   6.32e+08    136.083      0.000    8.48e+10    8.73e+10
# t           6.095e+08   3.58e+07     17.022      0.000    5.37e+08    6.82e+08
# Month_1     3.072e+10   7.02e+08     43.785      0.000    2.93e+10    3.21e+10
# Month_4     1.646e+10   7.08e+08     23.262      0.000     1.5e+10    1.79e+10
# Month_7     2.047e+10   7.15e+08     28.623      0.000     1.9e+10    2.19e+10
# Month_10     1.84e+10   7.37e+08     24.981      0.000    1.69e+10    1.99e+10
# ==============================================================================
# Omnibus:                        2.366   Durbin-Watson:                   0.338
# Prob(Omnibus):                  0.306   Jarque-Bera (JB):                1.341
# Skew:                           0.090   Prob(JB):                        0.512
# Kurtosis:                       2.110   Cond. No.                     8.95e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.38e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Predict Future

# %% [markdown]
# Now we can plug the values into the regression equation to get a forecast for any $t$. First determine what our last $t$ was so we can use the next $t$.

# %%
last_t = reg_df['t'].max()
t = last_t + 1
t
# Out:
# 39

# %% [markdown]
# Also determine which quarter is next, so we can use the appropriate dummmy.

# %%
last_q = reg_df.index.max()
last_q
# Out:
# Timestamp('2019-07-31 00:00:00')

# %% [markdown]
# The next quarter will end on 10/31, so we want `Month_10` set to 1 and the rest to 0. With the others 0, they drop out of the equation. So we can just do the intercept plus $t$ multiplied by its slope plus the appropriate dummy.

# %%
fcst = results.params['const'] + results.params['t'] * t + results.params['Month_10']
fcst
# Out:
# 128225479674.79666

# %% [markdown]
# It's kind of hard to see if it worked well with a single value. So let's use `pandas.date_range` to construct the future dates and fill in the forecast values for the next few years. Here I am starting the date range from the last quarter, advancing it in three month steps (`freq='3M'`), and ending it after 12 periods (3 years).

# %%
fcst_dates = pd.date_range(start=last_q, freq='3M', periods=12)
fcst_dates
# Out:
# DatetimeIndex(['2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30',
#                '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30',
#                '2021-07-31', '2021-10-31', '2022-01-31', '2022-04-30'],
#               dtype='datetime64[ns]', freq='3M')

# %% [markdown]
# Let's use a dictionary to collect the values, then create a series from the dictionary. Here we will need some logic to include the correct dummy and $t$.

# %%
forecasts = {}
for i, date in enumerate(fcst_dates):
    t_offset = i + 1
    t = last_t + t_offset
    month = date.month
    forecasts[date] = results.params['const'] + results.params['t'] * t + results.params[f'Month_{month}']
forecasts
# Out:
# {Timestamp('2019-07-31 00:00:00', freq='3M'): 130296889024.39017,
#  Timestamp('2019-10-31 00:00:00', freq='3M'): 128834936991.86984,
#  Timestamp('2020-01-31 00:00:00', freq='3M'): 141759518292.68283,
#  Timestamp('2020-04-30 00:00:00', freq='3M'): 128110218292.68283,
#  Timestamp('2020-07-31 00:00:00', freq='3M'): 132734718292.68283,
#  Timestamp('2020-10-31 00:00:00', freq='3M'): 131272766260.1625,
#  Timestamp('2021-01-31 00:00:00', freq='3M'): 144197347560.97552,
#  Timestamp('2021-04-30 00:00:00', freq='3M'): 130548047560.97551,
#  Timestamp('2021-07-31 00:00:00', freq='3M'): 135172547560.97552,
#  Timestamp('2021-10-31 00:00:00', freq='3M'): 133710595528.45518,
#  Timestamp('2022-01-31 00:00:00', freq='3M'): 146635176829.2682,
#  Timestamp('2022-04-30 00:00:00', freq='3M'): 132985876829.26819}

# %% [markdown]
# Now create the series.

# %%
fcst_series = pd.Series(forecasts)
fcst_series
# Out:
# 2019-07-31    1.302969e+11
# 2019-10-31    1.288349e+11
# 2020-01-31    1.417595e+11
# 2020-04-30    1.281102e+11
# 2020-07-31    1.327347e+11
# 2020-10-31    1.312728e+11
# 2021-01-31    1.441973e+11
# 2021-04-30    1.305480e+11
# 2021-07-31    1.351725e+11
# 2021-10-31    1.337106e+11
# 2022-01-31    1.466352e+11
# 2022-04-30    1.329859e+11
# dtype: float64

# %% [markdown]
# Now plot the series.

# %%
fcst_series.plot.line()

# %% [markdown]
# It seems to have the same pattern as the earlier data. Now double check by putting the historical and forecast together.

# %%
full_series = pd.concat([stmts.revenue, fcst_series])
full_series.plot.line()

# %% [markdown]
# Looks like we did a pretty good job!

# %% [markdown]
# ## Forecasting by Using the Automated Software Approach
#
# The previous approach worked well because we have regular quarterly data (they didn't change their quarter dates), we don't have any missing data, and the pattern was very consistent over time. These will not always be the case. When the time-series gets even more complex, more complex models are required, e.g. ARIMA, GARCH, but these are far outside the scope of the course. So what can we do if we have a very complex time series? Well there are experts out there who have already built in a process of selecting the best model, and released packages which make it easy to use.
#
# I have taken the best practices for forecasting and built it into the `finstmt` package, so we can look at using that. But under the hood, `finstmt` is using `fbprophet` as the main package which handles all the time-series forecasting. It is a package open-sourced by Facebook which they developed after running many, many forecasts at incredible scale. They are not even using standard time series models but have developed their own model which is more robust to missing and irregular data. It has wide-ranging applications beyond forecasting financial statement data. You can read more about the package here: https://facebook.github.io/prophet/

# %% [markdown]
# ### Install `fbprophet`

# %% [markdown]
# It's actually not the most straightforward to install `fbprophet`, because it's doing some pretty heavy stuff under the hood. To increase performance, it's actually compiling C++ code to run the models. So we can't install it like a normal package because it needs a C++ compiler to come along with it.
#
# In Windows search, type Anaconda, and see Anaconda Prompt come up in the results. Right click it, and you should see "Run as administrator". Click that and then Yes to allow changes to the device. Then you should see Administrator in the top of the terminal that comes up.

# %% [markdown]
# <img src="attachment:anaconda-prompt-admin.png" width="500">

# %% [markdown]
# In that terminal, type `conda install -c conda-forge fbprophet` and hit enter. It should take some time where it is saying things like "collecting package metadata" and "solving environment".

# %% [markdown]
# ![fbprophet-install-1.png](attachment:fbprophet-install-1.png)

# %% [markdown]
# After some time it will ask you whether to proceed. Type `y` and then hit enter.

# %% [markdown]
# <img src="attachment:fbprophet-install-2.png" width="500">

# %% [markdown]
#  It should then install all the packages. After a while, you should see a successful install.

# %% [markdown]
# <img src="attachment:fbprophet-install-3.png" width="500">

# %% [markdown]
# ## Upgrade `finstmt`
#
# I have added the forecasting functionality to `finstmt` since we last used it. Currently you have version `0.1.0` installed, but we need version `0.2.1` for the exercise. Thankfully we can just run a simple command here to update it. It's the same as the install command but with `--upgrade` added.

# %%
# !pip install --upgrade finstmt
# Out:
# Collecting finstmt
#   Downloading https://files.pythonhosted.org/packages/fc/6b/5885712a89b4a1296d74ef11e1669994bfe17dd02b92be67f3d4e73042eb/finstmt-0.2.1.tar.gz
# Requirement already satisfied, skipping upgrade: pandas in /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages (from finstmt) (0.25.3)
# Requirement already satisfied, skipping upgrade: sympy in /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages (from finstmt) (1.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages (from pandas->finstmt) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages (from pandas->finstmt) (2019.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages (from pandas->finstmt) (1.17.4)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages (from sympy->finstmt) (1.1.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/nick/.local/share/virtualenvs/fin-model-course-eIFMSc8A/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->finstmt) (1.13.0)
# Building wheels for collected packages: finstmt
#   Building wheel for finstmt (setup.py) ... done
#   Created wheel for finstmt: filename=finstmt-0.2.1-cp37-none-any.whl size=21432 sha256=b99b7c5778e0c1d8a9fa9592c05684d5c2873b68577cd10f2d6868852555b6ad
#   Stored in directory: /home/nick/.cache/pip/wheels/5c/74/49/e94a6058b0239472e077d6a41e0e283c37a4b7d9e0e608188a
# Successfully built finstmt
# Installing collected packages: finstmt
#   Found existing installation: finstmt 0.2.0
#     Uninstalling finstmt-0.2.0:
#       Successfully uninstalled finstmt-0.2.0
# Successfully installed finstmt-0.2.1
# WARNING: You are using pip version 19.2.2, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# After you run this, if you are not doing it before the exercise, you will need to restart the kernel and re-run loading the financial statements.

# %% [markdown]
# ## Run Forecasts

# %% [markdown]
# Forecasting the entire financial statements with `finstmt` is as easy as calling `.forecast`. You can pass to `.forecast` how many periods you want to forecast and the frequency. The default is to forecast 5 periods with annual frequency. Here we have quarterly data, so we will have to pass `3M` as the `freq`. Also we want to extend it to 12 periods.

# %%
fcst_stmts = stmts.forecast(periods=12, freq='3M')
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# Again, don't worry about all the warnings here. In future versions of `finstmt` I will hide these warnings and add a nice progress bar for the forecasts. Let's take a look at what it did.

# %%
fcst_stmts
# Out:
# FinancialStatements(income_statements=IncomeStatements(statements={Timestamp('2019-10-31 00:00:00'): IncomeStatementData(revenue=129051599368.48738, cogs=96718507902.69173, sga=27742352056.48742, int_exp=641234602.4544512, tax_exp=2217210109.8655386, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=27742352056.48742, ebit=4590739409.308235, ebt=3949504806.853784, net_income=1732294696.9882455), Timestamp('2020-01-31 00:00:00'): IncomeStatementData(revenue=141606952669.50336, cogs=106676669485.74724, sga=28564408239.16812, int_exp=632236583.2498218, tax_exp=2860434414.5111322, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28564408239.16812, ebit=6365874944.587997, ebt=5733638361.338176, net_income=2873203946.8270435), Timestamp('2020-04-30 00:00:00'): IncomeStatementData(revenue=129953756551.43515, cogs=97917763732.12144, sga=27513101049.49714, int_exp=595010458.1863898, tax_exp=2244303326.86163, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=27513101049.49714, ebit=4522891769.816566, ebt=3927881311.6301765, net_income=1683577984.7685466), Timestamp('2020-07-31 00:00:00'): IncomeStatementData(revenue=133086847675.86665, cogs=99634292020.31204, sga=28359612266.79112, int_exp=615605517.0000359, tax_exp=3432139288.6179967, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28359612266.79112, ebit=5092943388.763493, ebt=4477337871.763456, net_income=1045198583.1454597), Timestamp('2020-10-31 00:00:00'): IncomeStatementData(revenue=131749338817.84201, cogs=98803691300.89888, sga=28755446032.868893, int_exp=646453107.7325363, tax_exp=1882297409.482382, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28755446032.868893, ebit=4190201484.074238, ebt=3543748376.3417015, net_income=1661450966.8593194), Timestamp('2021-01-31 00:00:00'): IncomeStatementData(revenue=145533026021.95386, cogs=109728130435.35915, sga=30103973441.24406, int_exp=607742305.2225192, tax_exp=2702627799.975594, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=30103973441.24406, ebit=5700922145.350651, ebt=5093179840.128132, net_income=2390552040.152538), Timestamp('2021-04-30 00:00:00'): IncomeStatementData(revenue=132734331112.3502, cogs=100229794909.30354, sga=28067475633.103027, int_exp=632373687.2224419, tax_exp=2191320162.1943684, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28067475633.103027, ebit=4437060569.943634, ebt=3804686882.7211924, net_income=1613366720.526824), Timestamp('2021-07-31 00:00:00'): IncomeStatementData(revenue=136889100409.78296, cogs=102819646337.07623, sga=29031682648.930794, int_exp=634051357.865592, tax_exp=4089934926.420505, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=29031682648.930794, ebit=5037771423.775932, ebt=4403720065.91034, net_income=313785139.48983526), Timestamp('2021-10-31 00:00:00'): IncomeStatementData(revenue=135459141661.23834, cogs=101876336138.37473, sga=29347679213.136543, int_exp=654184001.3788934, tax_exp=2070547609.8943315, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=29347679213.136543, ebit=4235126309.7270737, ebt=3580942308.3481803, net_income=1510394698.4538488), Timestamp('2022-01-31 00:00:00'): IncomeStatementData(revenue=149631290465.34933, cogs=113653556732.13275, sga=30792174031.030273, int_exp=631094536.270637, tax_exp=2645608724.478988, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=30792174031.030273, ebit=5185559702.18631, ebt=455446 ...

# %% [markdown]
# We can see it has forecasted the entire financial statements 12 periods into the future. How did it get there? We can take a look at the assumptions used in the forecast.

# %%
fcst_stmts.forecast_assumptions
# Out:
#                                     Method        % of
# Revenue                               auto        None
# Cost of Goods Sold                    auto     revenue
# R&D Expense                           auto        None
# SG&A Expense                          auto        None
# Depreciation & Amortization Expense   auto        None
# Other Operating Expenses              auto        None
# Interest Expense                      auto  total_debt
# Gain on Sale of Investments           auto        None
# Gain on Sale of Assets                auto        None
# Impairment Expense                    auto        None
# Income Tax Expense                    auto         ebt
# Cash and Cash Equivalents             auto        None
# Short-Term Investments                auto        None
# Cash and Short-Term Investments       auto        None
# Receivables                           auto     revenue
# Inventory                             auto     revenue
# Deferred Tax Assets, Current          auto        None
# Other Current Assets                  auto        None
# Total Current Assets                  auto        None
# Grosss Property, Plant & Equipment    auto        None
# Accumulated Depreciation              auto        None
# Net Property, Plant & Equipment       auto        None
# Goodwill and Intangible Assets        auto        None
# Long-Term Investments                 auto        None
# Deferred Tax Assets, Long-Term        auto        None
# Other Long-Term Assets                auto        None
# Total Non-Current Assets              auto        None
# Total Assets                          auto        None
# Payables                              auto     revenue
# Short-Term Debt                       auto  total_debt
# Current Portion of Long-Term Debt     auto  total_debt
# Tax Liabilities, Short-Term           auto        None
# Other Current Liabilities             auto        None
# Total Current Liabilities             auto        None
# Long-Term Debt                        auto  total_debt
# Total Debt                            auto        None
# Deferred Revenue                      auto        None
# Tax Liabilities, Long-Term            auto        None
# Deposit Liabilities                   auto        None
# Other Long-Term Liabilities           auto        None
# Total Non-Current Liabilities         auto        None
# Total Liabilities                     auto        None
# Common Stock                          auto        None
# Other Comprehensive Income            auto        None
# Retained Earnings                     auto        None
# Minority Interest                     auto        None
# Total Stockholder's Equity            auto        None
# Total Liabilities and Equity          auto        None

# %% [markdown]
# All of them are using the method `auto` which means let `fbprophet` decide how to forecast it. Some items are being forecasted as percentages of other items. Let's take a closer look at some of these forecasts. After the forecast has run, in the forecast statements, a `.forecasts` dictionary is created, where it has keys of the same keys used to look up the financial items and values as a `Forecast` object. From this `Forecast` object we can get more information such as the model, as well as plots.

# %%
fig = fcst_stmts.forecasts['revenue'].plot()

# %% [markdown]
# We can see that `fbprophet` also did a good job with the patterns in the time series. It also has a nice plotting output which shows the historical points as well as the historical fit and the predictions, and confidence intervals for the predictions. We can also plot a decomposition of the forecast.

# %%
fig2 = fcst_stmts.forecasts['revenue'].plot_components()

# %% [markdown]
# We can see this forecast was split into two parts: a trend and a seasonality component. The two are combined together to create the forecast.
#
# For items which are forecasted as a percentage of another item, the forecast is actually on those percentages, then those percentages are combined with the other item to create the forecast. So when you view the plots it will be a plot of forecasting the percentages.

# %%
fig3 = fcst_stmts.forecasts['cogs'].plot()

# %%
fig4 = fcst_stmts.forecasts['cogs'].plot_components()

# %% [markdown]
# We can see it has even determined that there is a non-linear trend and fit, in addition to the seasonality component. We are certainly not going to be able to do this easily by ourselves. Let's just leave that to the experts.

# %% [markdown]
# ### Modifying `finstmt` Forecasts

# %% [markdown]
# `finstmt` has a configuration system so you can modify how any item is forecasted, and as well as do things like add custom names for items or add additional items. Let's look at how to update a forecast configuration using this configuration system.
#
# Say that the company we are forecasting has a very flexible workforce. They are able to hire labor when needed and lay them off when not. So the SG&A expense for this company in particular should be tied to sales, while this is typically not what you want for most companies. Let's update the forecast config to make SG&A forecasted as a percentage of sales.
#
# We can find via tab complete that the key for SG&A is `sga` and that for sales is `revenue`. We will use these keys for the config.

# %%
stmts.

# %% [markdown]
# The structure of a configuration object for an item is as shown.

# %%
sga_cfg = stmts.config.get('sga')
sga_cfg
# Out:
# ItemConfig(key='sga', display_name='SG&A Expense', extract_names=['sga', 'sga expense', 'sga expenses', 'sga exp', 'selling general and administrative', 'selling general and administrative expense', 'selling general and administrative expenses', 'selling general and administrative exp', 'selling general administrative', 'selling general administrative expense', 'selling general administrative expenses', 'selling general administrative exp', 'selling general and admin', 'selling general and admin expense', 'selling general and admin expenses', 'selling general and admin exp', 'selling general admin', 'selling general admin expense', 'selling general admin expenses', 'selling general admin exp'], force_positive=True, forecast_config=ForecastItemConfig(method='auto', pct_of=None, make_forecast=True, prophet_kwargs={}), expr_str=None)

# %% [markdown]
# We can see that in there it has `forecast_config=ForecastItemConfig(...)`, this is what we will want to modify. There are some convenience methods for doing this.

# %% [markdown]
# We can use `.config.get_value` to get specifically the forecast_config

# %%
fcst_cfg = stmts.config.get_value('sga', 'forecast_config')
fcst_cfg
# Out:
# ForecastItemConfig(method='auto', pct_of=None, make_forecast=True, prophet_kwargs={})

# %% [markdown]
# Now modify the config as we see fit.

# %%
fcst_cfg.pct_of = 'revenue'
fcst_cfg
# Out:
# ForecastItemConfig(method='auto', pct_of='revenue', make_forecast=True, prophet_kwargs={})

# %% [markdown]
# Now set that config back.

# %%
stmts.config.set_value('sga', 'forecast_config', fcst_cfg)

# %% [markdown]
# Now we can look at the forecast assumptions to see SG&A now is based off the revenue forecast.

# %%
stmts.forecast_assumptions
# Out:
#                                     Method        % of
# Revenue                               auto        None
# Cost of Goods Sold                    auto     revenue
# R&D Expense                           auto        None
# SG&A Expense                          auto     revenue
# Depreciation & Amortization Expense   auto        None
# Other Operating Expenses              auto        None
# Interest Expense                      auto  total_debt
# Gain on Sale of Investments           auto        None
# Gain on Sale of Assets                auto        None
# Impairment Expense                    auto        None
# Income Tax Expense                    auto         ebt
# Cash and Cash Equivalents             auto        None
# Short-Term Investments                auto        None
# Cash and Short-Term Investments       auto        None
# Receivables                           auto     revenue
# Inventory                             auto     revenue
# Deferred Tax Assets, Current          auto        None
# Other Current Assets                  auto        None
# Total Current Assets                  auto        None
# Grosss Property, Plant & Equipment    auto        None
# Accumulated Depreciation              auto        None
# Net Property, Plant & Equipment       auto        None
# Goodwill and Intangible Assets        auto        None
# Long-Term Investments                 auto        None
# Deferred Tax Assets, Long-Term        auto        None
# Other Long-Term Assets                auto        None
# Total Non-Current Assets              auto        None
# Total Assets                          auto        None
# Payables                              auto     revenue
# Short-Term Debt                       auto  total_debt
# Current Portion of Long-Term Debt     auto  total_debt
# Tax Liabilities, Short-Term           auto        None
# Other Current Liabilities             auto        None
# Total Current Liabilities             auto        None
# Long-Term Debt                        auto  total_debt
# Total Debt                            auto        None
# Deferred Revenue                      auto        None
# Tax Liabilities, Long-Term            auto        None
# Deposit Liabilities                   auto        None
# Other Long-Term Liabilities           auto        None
# Total Non-Current Liabilities         auto        None
# Total Liabilities                     auto        None
# Common Stock                          auto        None
# Other Comprehensive Income            auto        None
# Retained Earnings                     auto        None
# Minority Interest                     auto        None
# Total Stockholder's Equity            auto        None
# Total Liabilities and Equity          auto        None

# %% [markdown]
# Finally run the forecast again.

# %%
fcst_stmts = stmts.forecast(periods=12, freq='3M')
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fcst_stmts
# Out:
# FinancialStatements(income_statements=IncomeStatements(statements={Timestamp('2019-10-31 00:00:00'): IncomeStatementData(revenue=129051599368.48738, cogs=96718507902.69173, sga=27636010630.809464, int_exp=641234602.4544512, tax_exp=2276909058.3771377, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=27636010630.809464, ebit=4697080834.986191, ebt=4055846232.5317397, net_income=1778937174.154602), Timestamp('2020-01-31 00:00:00'): IncomeStatementData(revenue=141606952669.50336, cogs=106676669485.74724, sga=28318754471.21957, int_exp=632236583.2498218, tax_exp=2982987747.59759, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28318754471.21957, ebit=6611528712.536549, ebt=5979292129.286727, net_income=2996304381.689137), Timestamp('2020-04-30 00:00:00'): IncomeStatementData(revenue=129953756551.43515, cogs=97917763732.12144, sga=27256485965.313717, int_exp=595010458.1863898, tax_exp=2390927433.2088523, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=27256485965.313717, ebit=4779506853.999989, ebt=4184496395.8135986, net_income=1793568962.6047463), Timestamp('2020-07-31 00:00:00'): IncomeStatementData(revenue=133086847675.86665, cogs=99634292020.31204, sga=28026108175.490734, int_exp=615605517.0000359, tax_exp=3687789527.0968866, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28026108175.490734, ebit=5426447480.063877, ebt=4810841963.063841, net_income=1123052435.9669542), Timestamp('2020-10-31 00:00:00'): IncomeStatementData(revenue=131749338817.84201, cogs=98803691300.89888, sga=28390087833.89856, int_exp=646453107.7325363, tax_exp=2076361072.7058272, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28390087833.89856, ebit=4555559683.044571, ebt=3909106575.3120346, net_income=1832745502.6062074), Timestamp('2021-01-31 00:00:00'): IncomeStatementData(revenue=145533026021.95386, cogs=109728130435.35915, sga=29666294006.16726, int_exp=607742305.2225192, tax_exp=2934876541.5959997, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=29666294006.16726, ebit=6138601580.427452, ebt=5530859275.204933, net_income=2595982733.6089334), Timestamp('2021-04-30 00:00:00'): IncomeStatementData(revenue=132734331112.3502, cogs=100229794909.30354, sga=27489748321.958714, int_exp=632373687.2224419, tax_exp=2524063839.712297, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=27489748321.958714, ebit=5014787881.087948, ebt=4382414193.865506, net_income=1858350354.1532092), Timestamp('2021-07-31 00:00:00'): IncomeStatementData(revenue=136889100409.78296, cogs=102819646337.07623, sga=28376430149.77898, int_exp=634051357.865592, tax_exp=4698497696.486437, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28376430149.77898, ebit=5693023922.927746, ebt=5058972565.062154, net_income=360474868.575717), Timestamp('2021-10-31 00:00:00'): IncomeStatementData(revenue=135459141661.23834, cogs=101876336138.37473, sga=28723147841.017498, int_exp=654184001.3788934, tax_exp=2431659805.650875, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=28723147841.017498, ebit=4859657681.846119, ebt=4205473680.4672256, net_income=1773813874.8163505), Timestamp('2022-01-31 00:00:00'): IncomeStatementData(revenue=149631290465.34933, cogs=113653556732.13275, sga=29998645806.641144, int_exp=631094536.270637, tax_exp=3106555315.8098993, rd_exp=0.0, dep_exp=0.0, other_op_exp=0.0, gain_on_sale_invest=0.0, gain_on_sale_asset=0.0, impairment=0.0, op_exp=29998645806.641144, ebit=5979087926.575439, ebt=5347 ...

# %% [markdown]
# Now we can see that it has updated the forecast to be on a percetage of sales.

# %%
fig = fcst_stmts.forecasts['sga'].plot()

# %%
fig = fcst_stmts.forecasts['sga'].plot_components()

# %% [markdown]
# In future versions, I will be giving greater control over the forecasts, allowing different forecast methods and adjustment of the forecasts.
